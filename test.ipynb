# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv("dataFile.csv")
data
# Out:
#                             objid  crowded  badbkgmatch          ra  \
# 0      SSTSL2 J152742.67+023551.8        0            0  231.927823
# 1      SSTSL2 J053049.72-670554.9        0            0   82.707184
# 2      SSTSL2 J153607.88+384214.4        0            0  234.032847
# 3      SSTSL2 J224656.98+602924.5        0            0  341.737456
# 4      SSTSL2 J022523.15-733726.6        0            0   36.346464
# ...                           ...      ...          ...         ...
# 17459  SSTSL2 J053328.89-683636.5        0            0   83.370390
# 17460  SSTSL2 J194613.16+263840.3        1            0  296.554874
# 17461  SSTSL2 J193929.88+233823.8        1            0  294.874522
# 17462  SSTSL2 J174449.11-333318.8        1            0  266.204645
# 17463  SSTSL2 J170847.90-383627.4        1            0  257.199603
#
#              dec           l          b  nmatches  nreject  nbands  ...  \
# 0       2.597747    6.474539  45.311356         1        0       7  ...
# ...

# %%
df = pd.DataFrame(data, columns=['crowded','ra','dec'])
points = df.to_numpy()
points
# Out:
# array([[  0.      , 231.927823,   2.597747],
#        [  0.      ,  82.707184, -67.098598],
#        [  0.      , 234.032847,  38.704015],
#        ...,
#        [  1.      , 294.874522,  23.639946],
#        [  1.      , 266.204645, -33.555244],
#        [  1.      , 257.199603, -38.607616]])

# %%
for x in range(points.size):
    plt.plot(points[x,1], points[x,2], 'b*')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 2
#       1 for x in range(points.size):
# ----> 2     plt.plot(points[x,1], points[x,2], 'b*')
#       3 plt.show()
#
# IndexError: index 17464 is out of bounds for axis 0 with size 17464
