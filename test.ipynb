# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data= pd.read_csv("dataFile.csv")
data

# %%
data.head()
# Out:
#                         objid  crowded  badbkgmatch          ra        dec  \
# 0  SSTSL2 J152742.67+023551.8        0            0  231.927823   2.597747
# 1  SSTSL2 J053049.72-670554.9        0            0   82.707184 -67.098598
# 2  SSTSL2 J153607.88+384214.4        0            0  234.032847  38.704015
# 3  SSTSL2 J224656.98+602924.5        0            0  341.737456  60.490152
# 4  SSTSL2 J022523.15-733726.6        0            0   36.346464 -73.624064
#
#             l          b  nmatches  nreject  nbands  ...  E(BP-RP)  \
# 0    6.474539  45.311356         1        0       7  ...       NaN
# 1  277.220641 -32.640063         1        0       7  ...       NaN
# 2   62.261412  53.892852         1        0       7  ...       NaN
# 3  108.178973   1.234394         1        0       7  ...    0.2299
# 4  294.251396 -41.883553         1        0       7  ...    0.1264
#
#    b_E(BP-RP)_x  B_E(BP-RP)_xa      Lib     RAJ2000    DEJ2000  e_RAJ2000  \
# ...
