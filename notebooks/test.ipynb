# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import wget
data = pd.read_csv("../data/dataFile.csv")

# %%
ra= data['ra']
dec= data['dec']
plt.scatter(ra,dec)
plt.show()

# %%
id= data['objid']

### Create atlas.csv by combining series "objid","ra", and "dec" ###
# result = pd.DataFrame({'objid': id, 'ra': ra, 'dec': dec})
# result.to_csv('atlas.csv', index=False)
